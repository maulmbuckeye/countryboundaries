# %%
import os
os.getcwd()
os.chdir('..')

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

import countryborder as cb

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
geojson_file = 'src_data/data/countries.geojson'

# Read the GeoJSON file into a GeoDataFrame
gdf_raw = gpd.read_file(geojson_file)

# %%
gdf = gdf_raw.copy(deep=True)
gdf = cb.tidy_data(gdf)

# %%
gdf = cb.add_centroid(gdf)
# Out:
# C:\Users\Mike Ulm\code\countryborder_python\countryborder\tidy_data.py:20: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['centroid'] = gdf['geometry'].centroid

# %%
G = cb.create_country_network(gdf, 'ADMIN')
print('Done creating network')
cb.plot_country_network_on_map(gdf, G)
# Out:
# Done creating network

# %%
cb.plot_a_country_borders(G,'Germany')

# %%
cb.plot_a_country_borders(G,'France')

# %%
import countryborder as cb

# %%
cb.calculate_top_border_countries(G, 10)
# Out:
# China (14 borders): Afghanistan, Bhutan, India, Kazakhstan, Kyrgyzstan, Laos, Myanmar, Mongolia, Nepal, Pakistan, North Korea, Russia, Tajikistan, Vietnam
# Russia (14 borders): Azerbaijan, Belarus, China, Estonia, Finland, Georgia, Kazakhstan, Lithuania, Latvia, Mongolia, Norway, Poland, North Korea, Ukraine
# Brazil (10 borders): Argentina, Bolivia, Colombia, France, Guyana, Peru, Paraguay, Suriname, Uruguay, Venezuela
# Democratic Republic of the Congo (9 borders): Angola, Burundi, Central African Republic, Republic of Congo, Rwanda, South Sudan, United Republic of Tanzania, Uganda, Zambia
# Germany (9 borders): Austria, Belgium, Switzerland, Czech Republic, Denmark, France, Luxembourg, Netherlands, Poland
# France (9 borders): Andorra, Belgium, Brazil, Switzerland, Germany, Spain, Italy, Luxembourg, Suriname
# Austria (8 borders): Switzerland, Czech Republic, Germany, Hungary, Italy, Liechtenstein, Slovakia, Slovenia
# Turkey (8 borders): Armenia, Azerbaijan, Bulgaria, Georgia, Greece, Iran, Iraq, Syria
# United Republic of Tanzania (8 borders): Burundi, Democratic Republic of the Congo, Kenya, Mozambique, Malawi, Rwanda, Uganda, Zambia
# Zambia (8 borders): Angola, Botswana, Democratic Republic of the Congo, Mozambique, Malawi, Namibia, United Republic of Tanzania, Zimbabwe

# %%
cb.plot_a_country_borders(G,'Israel')

# %%
cb.find_shortest_path_between_countries(G, 'Israel', 'Finland')
# Out:
# Minimum number of borders to go from Israel to Finland : 5
# Countries to cross:
# Israel -> Syria
# Syria -> Turkey
# Turkey -> Azerbaijan
# Azerbaijan -> Russia
# Russia -> Finland

# %%
cb.find_shortest_path_between_countries(G, 'China', 'Canada')
# Out:
# Minimum number of borders to go from China to Canada : 14
# Countries to cross:
# China -> Russia
# Russia -> Poland
# Poland -> Germany
# Germany -> France
# France -> Brazil
# Brazil -> Colombia
# Colombia -> Panama
# Panama -> Costa Rica
# Costa Rica -> Nicaragua
# Nicaragua -> Honduras
# Honduras -> Guatemala
# Guatemala -> Mexico
# Mexico -> United States of America
# United States of America -> Canada

# %%
cb.plot_a_country_borders(G,'China')

# %%
gdf.tail(40)
# Out:
#                            ADMIN ISO_A3 ISO_A2  \
# 190                      Romania    ROU     RO
# 191                       Russia    RUS     RU
# 192                       Rwanda    RWA     RW
# 194                 Saudi Arabia    SAU     SA
# 196                        Sudan    SDN     SD
# 197                  South Sudan    SSD     SS
# 198                      Senegal    SEN     SN
# 200                    Singapore    SGP     SG
# 204                 Sierra Leone    SLE     SL
# 205                  El Salvador    SLV     SV
# 208                      Somalia    SOM     SO
# 210           Republic of Serbia    SRB     RS
# 212                     Suriname    SUR     SR
# 213                     Slovakia    SVK     SK
# 214                     Slovenia    SVN     SI
# 215                       Sweden    SWE     SE
# 216                    Swaziland    SWZ     SZ
# 218                   Seychelles    SYC     SC
# 219                        Syria    SYR     SY
# 221                         Chad    TCD     TD
# 222                         Togo    TGO     TG
# 223                     Thailand    THA     TH
# 224                   Tajikistan    TJK     TJ
# 225                 Turkmenistan    TKM     TM
# 226                   East Timor    TLS     TL
# 229                      Tunisia    TUN     TN
# 230                       Turkey    TUR     TR
# 232                       Taiwan    TWN     TW
# 233  United Republic of Tanzania    TZA     TZ
# 234                       Uganda    UGA     UG
# 235                      Ukraine    UKR     UA
# 237                      Uruguay    URY     UY
# 238     United States of America    USA     US
# 240                   Uzbekistan    UZB     UZ
# 243                    Venezuela    VEN     VE
# 246                      Vietnam    VNM     VN
# 251                        Yemen    YEM     YE
# 252                 South Africa    ZAF     ZA
# 253                       Zambia    ZMB     ZM
# 254                     Zimbabwe    ZWE     ZW
#
#                                               geometry   latitude   longitude
# 190  MULTIPOLYGON (((26.72238 48.25977, 26.73313 48...  45.853464   24.972942
# 191  MULTIPOLYGON (((132.44899 42.84540, 132.44988 ...  61.984555   96.693761
# 192  MULTIPOLYGON (((30.47179 -1.06684, 30.46386 -1...  -1.992751   29.919061
# 194  MULTIPOLYGON (((41.89847 16.75148, 41.90514 16...  24.122327   44.536864
# 196  MULTIPOLYGON (((37.26450 20.74999, 37.25441 20...  15.986881   29.939618
# 197  MULTIPOLYGON (((33.96912 9.83834, 33.90489 9.7...   7.283531   30.301120
# 198  MULTIPOLYGON (((-14.91250 16.64064, -14.88201 ...  14.367789  -14.471306
# 200  MULTIPOLYGON (((103.96079 1.39110, 103.98569 1...   1.358921  103.813468
# 204  MULTIPOLYGON (((-12.59586 7.61274, -12.58605 7...   8.563086  -11.795016
# 205  MULTIPOLYGON (((-87.69700 13.17806, -87.69319 ...  13.735849  -88.870923
